# %%
import pandas as pd

# %%
df=pd.read_csv("/home/jose/Jupyter_Notebooks/Youtube/Pandas/Data/Data.csv" ,encoding = "ISO-8859-1")

# %%
#Informacion del archivo
filas=len(df.index)
filas
# Out:
# 46652

# %%
#informacion del dataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46651 entries, 0 to 46650
# Data columns (total 54 columns):
# ATP           46651 non-null int64
# Location      46651 non-null object
# Tournament    46651 non-null object
# Date          46651 non-null object
# Series        46651 non-null object
# Court         46651 non-null object
# Surface       46651 non-null object
# Round         46651 non-null object
# Best of       46651 non-null int64
# Winner        46651 non-null object
# Loser         46651 non-null object
# WRank         46636 non-null object
# LRank         46580 non-null object
# W1            46422 non-null float64
# L1            46422 non-null float64
# W2            45961 non-null float64
# L2            45962 non-null float64
# W3            21364 non-null float64
# L3            21364 non-null float64
# W4            4226 non-null float64
# L4            4226 non-null float64
# W5            1617 non-null float64
# L5            1617 non-null float64
# ...

# %%
#ultimas fila
df.tail(5)
# Out:
#        ATP        Location           Tournament        Date  Series   Court  \
# 46647   54  St. Petersburg  St. Petersburg Open  23/09/2016  ATP250  Indoor
# 46648   54  St. Petersburg  St. Petersburg Open  23/09/2016  ATP250  Indoor
# 46649   54  St. Petersburg  St. Petersburg Open  24/09/2016  ATP250  Indoor
# 46650   54  St. Petersburg  St. Petersburg Open  24/09/2016  ATP250  Indoor
# 46651   54  St. Petersburg  St. Petersburg Open  25/09/2016  ATP250  Indoor
#
#       Surface          Round  Best of       Winner  ...  UBW UBL   LBW   LBL  \
# 46647    Hard  Quarterfinals        3    Zverev A.  ...  NaN NaN  1.57  2.38
# 46648    Hard  Quarterfinals        3  Wawrinka S.  ...  NaN NaN  1.22  4.33
# 46649    Hard     Semifinals        3    Zverev A.  ...  NaN NaN  2.38  1.57
# 46650    Hard     Semifinals        3  Wawrinka S.  ...  NaN NaN  1.33  3.40
# 46651    Hard      The Final        3    Zverev A.  ...  NaN NaN  3.30  1.33
#
#        SJW  SJL  MaxW  MaxL  AvgW  AvgL
# ...

# %%
#Eliminar la ultima fila
#drop quitar eliminar
#filas menos-1 por que el cero cuenta
#inplace =True para que se lleve a acabo
df.drop(df.index[[filas-1]],inplace=True)
df.tail(5)
# Out:
#        ATP        Location           Tournament        Date  Series   Court  \
# 46646   54  St. Petersburg  St. Petersburg Open  23/09/2016  ATP250  Indoor
# 46647   54  St. Petersburg  St. Petersburg Open  23/09/2016  ATP250  Indoor
# 46648   54  St. Petersburg  St. Petersburg Open  23/09/2016  ATP250  Indoor
# 46649   54  St. Petersburg  St. Petersburg Open  24/09/2016  ATP250  Indoor
# 46650   54  St. Petersburg  St. Petersburg Open  24/09/2016  ATP250  Indoor
#
#       Surface          Round  Best of            Winner  ...  UBW UBL   LBW  \
# 46646    Hard  Quarterfinals        3  Bautista Agut R.  ...  NaN NaN  1.36
# 46647    Hard  Quarterfinals        3         Zverev A.  ...  NaN NaN  1.57
# 46648    Hard  Quarterfinals        3       Wawrinka S.  ...  NaN NaN  1.22
# 46649    Hard     Semifinals        3         Zverev A.  ...  NaN NaN  2.38
# 46650    Hard     Semifinals        3       Wawrinka S.  ...  NaN NaN  1.33
#
#         LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL
# ...
