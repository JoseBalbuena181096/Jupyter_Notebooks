# %%
import pandas as pd

# %%
datos=pd.read_csv("/home/jose/Jupyter_Notebooks/Youtube/Pandas/Data/Data.csv" ,encoding = "ISO-8859-1")

# %%
datos.head()
# Out:
#    ATP  Location                          Tournament       Date  \
# 0    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 1    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 2    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 3    1  Adelaide  Australian Hardcourt Championships  3/01/2000
# 4    1  Adelaide  Australian Hardcourt Championships  3/01/2000
#
#           Series    Court Surface      Round  Best of       Winner  ...  UBW  \
# 0  International  Outdoor    Hard  1st Round        3   Dosedel S.  ...  NaN
# 1  International  Outdoor    Hard  1st Round        3   Enqvist T.  ...  NaN
# 2  International  Outdoor    Hard  1st Round        3    Escude N.  ...  NaN
# 3  International  Outdoor    Hard  1st Round        3   Federer R.  ...  NaN
# 4  International  Outdoor    Hard  1st Round        3  Fromberg R.  ...  NaN
#
#   UBL LBW  LBL  SJW  SJL  MaxW  MaxL  AvgW  AvgL
# 0 NaN NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN
# ...

# %%
#Fijamos un indice location
datos.set_index("Location",inplace=True)
#Datos
datos.loc[datos["Court"]=="Outdoor",["Surface"]]
# Out:
#          Surface
# Location
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# Adelaide    Hard
# ...          ...
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# New York    Hard
# ...

# %%
#Busqueda de Location , surfaces and winner
datos.loc[datos["Court"]=="Outdoor",["Surface","Winner"]]
# Out:
#          Surface          Winner
# Location
# Adelaide    Hard      Dosedel S.
# Adelaide    Hard      Enqvist T.
# Adelaide    Hard       Escude N.
# Adelaide    Hard      Federer R.
# Adelaide    Hard     Fromberg R.
# Adelaide    Hard    Gambill J.M.
# Adelaide    Hard     Grosjean S.
# Adelaide    Hard       Henman T.
# Adelaide    Hard       Hewitt L.
# Adelaide    Hard      Lisnard J.
# Adelaide    Hard       Martin A.
# Adelaide    Hard       Norman M.
# Adelaide    Hard     Petrovic D.
# Adelaide    Hard      Sekulov J.
# Adelaide    Hard  Stoltenberg J.
# Adelaide    Hard        Vinck C.
# Adelaide    Hard      Enqvist T.
# Adelaide    Hard       Escude N.
# Adelaide    Hard     Grosjean S.
# Adelaide    Hard       Henman T.
# Adelaide    Hard       Hewitt L.
# Adelaide    Hard       Martin A.
# Adelaide    Hard       Norman M.
# Adelaide    Hard  Stoltenberg J.
# Adelaide    Hard      Enqvist T.
# Adelaide    Hard       Escude N.
# Adelaide    Hard       Hewitt L.
# ...

# %%
#Mas de una condicion
datos.loc[datos["Series"].str.endswith("Slam")&(datos["Surface"]=="Clay")&(datos["Winner"]=="Federer R.")&(datos["Round"]=="The Final")]
# Out:
#           ATP   Tournament       Date      Series    Court Surface      Round  \
# Location
# Paris      31  French Open  7/06/2009  Grand Slam  Outdoor    Clay  The Final
#
#           Best of      Winner         Loser  ...    UBW  UBL    LBW  LBL  \
# Location                                     ...
# Paris           5  Federer R.  Soderling R.  ...   1.26  4.0  1.222  4.0
#
#            SJW  SJL  MaxW  MaxL  AvgW  AvgL
# Location
# Paris     1.25  4.0   NaN   NaN   NaN   NaN
#
# [1 rows x 53 columns]
