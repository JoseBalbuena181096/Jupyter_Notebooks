# %%
import pandas as pd
df=pd.read_csv("datos-misteriosos.csv")
df.head()
# Out:
#   dataset        x        y
# 0  clase1  55.3846  97.1795
# 1  clase1  51.5385  96.0256
# 2  clase1  46.1538  94.4872
# 3  clase1  42.8205  91.4103
# 4  clase1  40.7692  88.3333

# %%
#Primero observamos que valores hay en el dataset
df.dataset.unique()
# Out:
# array(['clase1', 'clase2'], dtype=object)

# %%
#Obtenemos los valores solo de la clase1
clase_1=df[df.dataset=="clase1"]
#Graficamos estos valores
# %matplotlib notebook
clase_1.plot.scatter(x="x",y="y",title="Datos misteriosos clase 1")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#Para los datos de segunda clase
clase_2=df[df.dataset=="clase2"]
#Ploteamos la clase 2
# %matplotlib notebook
clase_2.plot.scatter(x="x",y="y",title="Datos Misteriosos clase 2")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
