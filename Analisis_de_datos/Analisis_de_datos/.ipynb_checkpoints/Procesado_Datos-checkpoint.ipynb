# %%
# %load_ext watermark
# %watermark
# Out:
# 2018-12-30T12:45:31-06:00
#
# CPython 3.6.7
# IPython 7.2.0
#
# compiler   : GCC 8.2.0
# system     : Linux
# release    : 4.15.0-43-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %% [markdown]
# En esta seccion vamos a ver diversas formas de procesar un dataset.Por procesamiento(tambien llamado limpieza), nos referimos a
# preparar el dataset para la creacion de modelos predictivos.

# %% [markdown]
# # Descripcion
# Vamos a usar el mismo dataset que usamos en el ejemplo de Analisis Exploratorio de Datos.
# El dataset consiste en informacion relativa a vehiculos vendidos en USA desde 1985. Dicha informacion incluyente detalles tecnicos(cilindrada,tipo de trasmision) y detalles medioambientales(consumo de gasolina, emisiones de CO2)
# El archivo original esta en:        El archivo que vamos a usar es una version modificada(con menos columnas)
#
# Descripcion del dataset original
#
# ##### En la seccion de análisis de datos detectamos los siguientes errores en el dataset original:
# - Hay 1506 records duplicados
# - Las variables desplazamiento, cilindros, transmision y traccion tiene valores inexixtentes
# - Hay un outlier en las variables co2 y consumo
# - Hay coches hibridos y electricos(hemos removido estos ultimos ya que no generan contaminacion)
# - Ninguna variable numerica sigue una distribucion normal

# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"]=(12,12)

# %%
vehiculos=(pd
           .read_csv("/home/jose/data/vehiculos-original.csv")
           .rename(columns={
               "cylinders":"cilindros",
               "trany":"transmision",
               "make":"fabricante",
               "displ":"desplazamiento",#volumen del desplazamiento del motor
               "drive":"traccion",
               "VClass":"clase",
               "fuelType":"combustible",
               "comb08":"consumo",#combined MPG for fuelType1
               "co2TailpipeGpm":"co2",#tailpipe CO2 in grams/mile
           })
           .query("co2>0")
)

# %%
vehiculos.shape
# Out:
# (38297, 11)

# %% [markdown]
# ### Records Duplicados

# %% [markdown]
# Usamos la función de pandas drop_duplicates para remover los records duplicados

# %%
vehiculos=vehiculos.drop_duplicates()

# %%
vehiculos.shape
# Out:
# (36791, 11)

# %% [markdown]
# # Valores Extremos(outliers)
# Son valores que se alejan mas de de lo normal de la distribucion normal, se eliminaran aquellos que tengan un valor z  mayor de tres lo que es 3 desviaciones estandares.

# %%
from scipy import stats
import numpy as np

# %% [markdown]
# ### Averiguamos cuales de nuestras columnas con  outliers

# %%
def outliers_col(df):
    for columna in df:
        if df[columna].dtype != np.object:
            n_outliers=len(df[np.abs(stats.zscore(df[columna]))>3])
            print("{}| {} |{}".format(
                df[columna].name,
                n_outliers,
                df[columna].dtype
            ))
outliers_col(vehiculos)
# Out:
# year| 0 |int64
# desplazamiento| 0 |float64
# cilindros| 0 |float64
# consumo| 406 |int64
# co2| 243 |float64
# /home/jose/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in greater
#   after removing the cwd from sys.path.

# %%
vehiculos.describe()
# Out:
#                year  desplazamiento     cilindros       consumo           co2
# count  38297.000000    38295.000000  38294.000000  38297.000000  38297.000000
# mean    2000.298170        3.314394      5.733535     19.987936    473.802726
# std       10.531561        1.360686      1.753493      5.091338    119.127591
# min     1984.000000        0.600000      2.000000      7.000000     29.000000
# 25%     1991.000000        2.200000      4.000000     17.000000    389.000000
# 50%     2001.000000        3.000000      6.000000     19.000000    467.736842
# 75%     2010.000000        4.300000      6.000000     23.000000    553.000000
# max     2018.000000        8.400000     16.000000     58.000000   1269.571429

# %% [markdown]
# Obtenemos  valores que se encuentran dentro de un valor z de 3 para consumo y co2

# %%
#Calculamos la media del consumo de los veiculos y le restamos 3 veces la desviacion estandar del consumo
consumo_min=vehiculos.consumo.mean()-3*vehiculos.consumo.std()
#Calculamos la media del consumo de los veiculos y le sumamos 3 veces la desviacion estandar del consumo
consumo_max=vehiculos.consumo.mean()+3*vehiculos.consumo.std()
print(consumo_min,consumo_max)
co2_min=vehiculos.co2.mean()-3*vehiculos.co2.std()
co2_max=vehiculos.co2.mean()+3*vehiculos.co2.std()
print(co2_min,co2_max)
# Out:
# 4.713921339724962 35.261951444044
# 116.41995386416284 831.1854972689141

# %% [markdown]
# Para eliminar los columnas con valores z  mayores a 3
# Filtramos por columna

# %%
vehiculos=vehiculos[(np.abs(stats.zscore(vehiculos.consumo))<3) & \
                    (np.abs(stats.zscore(vehiculos.co2))<3)
                   ]

# %%
vehiculos.describe()
# Out:
#                year  desplazamiento     cilindros       consumo           co2
# count  37663.000000    37661.000000  37660.000000  37663.000000  37663.000000
# mean    2000.312163        3.317137      5.735927     19.827789    473.790389
# std       10.500399        1.340959      1.729149      4.574947    110.815512
# min     1984.000000        0.900000      2.000000      9.000000    144.000000
# 25%     1991.000000        2.200000      4.000000     17.000000    396.000000
# 50%     2001.000000        3.000000      6.000000     19.000000    467.736842
# 75%     2010.000000        4.300000      6.000000     23.000000    547.000000
# max     2018.000000        8.400000     12.000000     35.000000    829.000000

# %% [markdown]
# Vemos que aunque hemos removido los outliers, al haber cambiado la distribucion del dataset se generan nuevos outliers.

# %%
outliers_col(vehiculos)
# Out:
# year| 0 |int64
# desplazamiento| 0 |float64
# cilindros| 0 |float64
# consumo| 225 |int64
# co2| 458 |float64
# /home/jose/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in greater
#   after removing the cwd from sys.path.

# %% [markdown]
# Para eliminar estos simplemente repetimos el proceso hasta que no queden valores extremos.

# %%
vehiculos=vehiculos[(np.abs(stats.zscore(vehiculos.consumo))<3) &\
                    (np.abs(stats.zscore(vehiculos.co2))<3)
                   ]

# %%
outliers_col(vehiculos)
# Out:
# year| 0 |int64
# desplazamiento| 0 |float64
# cilindros| 0 |float64
# consumo| 156 |int64
# co2| 9 |float64
# /home/jose/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in greater
#   after removing the cwd from sys.path.

# %%
vehiculos.shape
# Out:
# (36980, 11)

# %% [markdown]
# # Valores inexistentes

# %%
#Porcentaje de valores inexistentes
n_records=len(vehiculos)
def valores_inexistentes_col(df):
    for columna in df:
        print("{} |{}%| {}".format(
            df[columna].name,
            len(df[df[columna].isnull()])/(1.0*n_records)*100,
            df[columna].dtype
        ))
valores_inexistentes_col(vehiculos)
# Out:
# fabricante |0.0%| object
# model |0.0%| object
# year |0.0%| int64
# desplazamiento |0.005408328826392645%| float64
# cilindros |0.008112493239588967%| float64
# transmision |0.0027041644131963224%| object
# traccion |3.0232558139534884%| object
# clase |0.0%| object
# combustible |0.0%| object
# consumo |0.0%| int64
# co2 |0.0%| float64

# %% [markdown]
# Muchos algoritmos de Machine Learning requieren que no existan valores inexixtententes(o NaN como se llama a veces).
# Hay varias técnicas para tratar dichos valores:
#     1. Eliminar records con valores inexistentes

# %%
vehiculos_sin_null=vehiculos.dropna(subset=["desplazamiento","transmision","traccion"])

# %%
vehiculos_sin_null.shape
# Out:
# (35859, 11)

# %% [markdown]
# 2.Remplazar los valores inexixtentes con un valor en particular. Por ejemplo 0 o "null". Es una forma simple de tratar estos valores pero añade un monton de ruido(asume que los valres inexistenteslo son por un motivo en concreto).

# %%
vehiculos["transmision_imp"]=vehiculos.transmision.fillna("sin transmision")
vehiculos["desplazamiento_imp"]=vehiculos.desplazamiento.fillna(0)
vehiculos["cilindros_imp"]=vehiculos.cilindros.fillna(0)

# %%
vehiculos
# Out:
#                   fabricante                model  year  desplazamiento  \
# 0                 AM General    DJ Po Vehicle 2WD  1984             2.5
# 1                 AM General    DJ Po Vehicle 2WD  1984             2.5
# 2                 AM General     FJ8c Post Office  1984             4.2
# 3                 AM General     FJ8c Post Office  1984             4.2
# 4                 AM General  Post Office DJ5 2WD  1985             2.5
# 5                 AM General  Post Office DJ8 2WD  1985             4.2
# 6           ASC Incorporated                  GNX  1987             3.8
# 7                      Acura          2.2CL/3.0CL  1997             2.2
# 8                      Acura          2.2CL/3.0CL  1997             2.2
# 9                      Acura          2.2CL/3.0CL  1997             3.0
# 10                     Acura          2.3CL/3.0CL  1998             2.3
# 11                     Acura          2.3CL/3.0CL  1998             2.3
# 12                     Acura          2.3CL/3.0CL  1998             3.0
# 13                     Acura          2.3CL/3.0CL  1999             2.3
# 14                     Acura          2.3CL/3.0CL  1999             2.3
# 15                     Acura          2.3CL/3.0CL  1999             3.0
# 16                     Acura                2.5TL  1995             2.5
# 17                     Acura          2.5TL/3.2TL  1996             2.5
# 18                     Acura          2.5TL/3.2TL  1996             3.2
# 19                     Acura          2.5TL/3.2TL  1997             2.5
# 20                     Acura          2.5TL/3.2TL  1997             3.2
# 21                     Acura          2.5TL/3.2TL  1998             2.5
# 22                     Acura          2.5TL/3.2TL  1998             3.2
# 23                     Acura                3.2CL  2001             3.2
# 24                     Acura                3.2CL  2002             3.2
# 25                     Acura                3.2CL  2003             3.2
# 26                     Acura                3.2CL  2003             3.2
# 27                     Acura                3.2TL  1999             3.2
# 28                     Acura                3.2TL  2000             3.2
# 29                     Acura                3.2TL  2001             3.2
# ...                      ...                  ...   ...             ...
# 38370  Wallace Environmental           Wetl 300 E  1991             2.9
# 38371  Wallace Environmental           Wetl 300 E  1992             2.9
# 38372  Wallace Environmental          Wetl 300 GE  1991             2.9
# 38373  Wallace Environmental          Wetl 300 SL  1991             2.9
# 38374  Wallace Environmental          Wetl 300 SL  1992             2.9
# 38375  Wallace Environmental          Wetl 300 TE  1991             2.9
# 38376  Wallace Environmental          Wetl 300 TE  1992             2.9
# 38379  Wallace Environmental          Wetl 500 SE  1991             5.6
# 38380  Wallace Environmental          Wetl 500 SE  1992             5.6
# 38381  Wallace Environmental         Wetl 500 SEC  1991             5.6
# 38382  Wallace Environmental         Wetl 500 SEC  1992             5.6
# 38383  Wallace Environmental         Wetl 500 SEL  1991             5.6
# 38384  Wallace Environmental         Wetl 500 SEL  1992             5.6
# 38385  Wallace Environmental          Wetl 500 SL  1991             5.6
# 38386  Wallace Environmental         Wetl 560 SEC  1991             5.6
# 38387  Wallace Environmental         Wetl 560 SEC  1992             5.6
# 38388  Wallace Environmental         Wetl 560 SEL  1991             5.6
# 38389  Wallace Environmental         Wetl 560 SEL  1992             5.6
# 38390  Wallace Environmental          Wetl 560 SL  1991             5.6
# 38391  Wallace Environmental         Wetl 600 SEL  1992             6.0
# 38392  Wallace Environmental            Wetl 850I  1992             5.0
# 38393  Wallace Environmental            Wetl 850I  1992             5.0
# 38396                   Yugo                   GV  1988             1.1
# 38397                   Yugo                   GV  1988             1.3
# 38398                   Yugo    GV Plus/GV/Cabrio  1990             1.3
# 38399                   Yugo    GV Plus/GV/Cabrio  1990             1.3
# 38400                   Yugo               GV/GVX  1987             1.1
# 38401                   Yugo               GV/GVX  1989             1.1
# 38402                   Yugo               GV/GVX  1989             1.3
# 38403                   Yugo          Gy/yugo GVX  1986             1.1
#
#        cilindros      transmision                    traccion  \
# 0            4.0  Automatic 3-spd               2-Wheel Drive
# 1            4.0  Automatic 3-spd               2-Wheel Drive
# 2            6.0  Automatic 3-spd               2-Wheel Drive
# 3            6.0  Automatic 3-spd               2-Wheel Drive
# 4            4.0  Automatic 3-spd            Rear-Wheel Drive
# 5            6.0  Automatic 3-spd            Rear-Wheel Drive
# 6            6.0  Automatic 4-spd            Rear-Wheel Drive
# 7            4.0  Automatic 4-spd           Front-Wheel Drive
# 8            4.0     Manual 5-spd           Front-Wheel Drive
# 9            6.0  Automatic 4-spd           Front-Wheel Drive
# 10           4.0  Automatic 4-spd           Front-Wheel Drive
# 11           4.0     Manual 5-spd           Front-Wheel Drive
# 12           6.0  Automatic 4-spd           Front-Wheel Drive
# 13           4.0  Automatic 4-spd           Front-Wheel Drive
# 14           4.0     Manual 5-spd           Front-Wheel Drive
# 15           6.0  Automatic 4-spd           Front-Wheel Drive
# 16           5.0  Automatic 4-spd           Front-Wheel Drive
# 17           5.0  Automatic 4-spd           Front-Wheel Drive
# 18           6.0  Automatic 4-spd           Front-Wheel Drive
# 19           5.0  Automatic 4-spd           Front-Wheel Drive
# 20           6.0  Automatic 4-spd           Front-Wheel Drive
# 21           5.0  Automatic 4-spd           Front-Wheel Drive
# 22           6.0  Automatic 4-spd           Front-Wheel Drive
# 23           6.0   Automatic (S5)           Front-Wheel Drive
# 24           6.0   Automatic (S5)           Front-Wheel Drive
# 25           6.0     Manual 6-spd           Front-Wheel Drive
# 26           6.0   Automatic (S5)           Front-Wheel Drive
# 27           6.0  Automatic 4-spd           Front-Wheel Drive
# 28           6.0  Automatic 5-spd           Front-Wheel Drive
# 29           6.0   Automatic (S5)           Front-Wheel Drive
# ...          ...              ...                         ...
# 38370        6.0  Automatic 4-spd            Rear-Wheel Drive
# 38371        6.0  Automatic 4-spd            Rear-Wheel Drive
# 38372        6.0  Automatic 4-spd  4-Wheel or All-Wheel Drive
# 38373        6.0  Automatic 4-spd            Rear-Wheel Drive
# 38374        6.0  Automatic 4-spd            Rear-Wheel Drive
# 38375        6.0  Automatic 4-spd            Rear-Wheel Drive
# 38376        6.0  Automatic 4-spd            Rear-Wheel Drive
# 38379        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38380        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38381        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38382        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38383        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38384        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38385        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38386        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38387        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38388        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38389        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38390        8.0  Automatic 4-spd            Rear-Wheel Drive
# 38391       12.0  Automatic 4-spd            Rear-Wheel Drive
# 38392       12.0  Automatic 4-spd            Rear-Wheel Drive
# 38393       12.0     Manual 6-spd            Rear-Wheel Drive
# 38396        4.0     Manual 4-spd           Front-Wheel Drive
# 38397        4.0     Manual 5-spd           Front-Wheel Drive
# 38398        4.0     Manual 4-spd           Front-Wheel Drive
# 38399        4.0     Manual 5-spd           Front-Wheel Drive
# 38400        4.0     Manual 4-spd           Front-Wheel Drive
# 38401        4.0     Manual 4-spd           Front-Wheel Drive
# 38402        4.0     Manual 5-spd           Front-Wheel Drive
# 38403        4.0     Manual 4-spd           Front-Wheel Drive
#
#                               clase combustible  consumo         co2  \
# 0       Special Purpose Vehicle 2WD     Regular       17  522.764706
# 1       Special Purpose Vehicle 2WD     Regular       17  522.764706
# 2       Special Purpose Vehicle 2WD     Regular       13  683.615385
# 3       Special Purpose Vehicle 2WD     Regular       13  683.615385
# 4       Special Purpose Vehicle 2WD     Regular       16  555.437500
# 5       Special Purpose Vehicle 2WD     Regular       13  683.615385
# 6                      Midsize Cars     Premium       16  555.437500
# 7                   Subcompact Cars     Regular       22  403.954545
# 8                   Subcompact Cars     Regular       24  370.291667
# 9                   Subcompact Cars     Regular       20  444.350000
# 10                  Subcompact Cars     Regular       22  403.954545
# 11                  Subcompact Cars     Regular       24  370.291667
# 12                  Subcompact Cars     Regular       20  444.350000
# 13                  Subcompact Cars     Regular       22  403.954545
# 14                  Subcompact Cars     Regular       24  370.291667
# 15                  Subcompact Cars     Regular       20  444.350000
# 16                     Compact Cars     Premium       20  444.350000
# 17                     Compact Cars     Premium       20  444.350000
# 18                     Compact Cars     Premium       19  467.736842
# 19                     Compact Cars     Premium       20  444.350000
# 20                     Compact Cars     Premium       19  467.736842
# 21                     Compact Cars     Premium       20  444.350000
# 22                     Compact Cars     Premium       19  467.736842
# 23                     Compact Cars     Premium       20  444.350000
# 24                     Compact Cars     Premium       21  423.190476
# 25                     Compact Cars     Premium       20  444.350000
# 26                     Compact Cars     Premium       21  423.190476
# 27                     Midsize Cars     Premium       20  444.350000
# 28                     Midsize Cars     Premium       20  444.350000
# 29                     Midsize Cars     Premium       20  444.350000
# ...                             ...         ...      ...         ...
# 38370                  Compact Cars     Premium       15  592.466667
# 38371                  Compact Cars     Premium       15  592.466667
# 38372      Special Purpose Vehicles     Premium       12  740.583333
# 38373              Minicompact Cars     Premium       15  592.466667
# 38374              Minicompact Cars     Premium       15  592.466667
# 38375  Midsize-Large Station Wagons     Premium       15  592.466667
# 38376  Midsize-Large Station Wagons     Premium       15  592.466667
# 38379                  Compact Cars     Premium       13  683.615385
# 38380                  Compact Cars     Premium       13  683.615385
# 38381                  Compact Cars     Premium       13  683.615385
# 38382                  Compact Cars     Premium       13  683.615385
# 38383                  Midsize Cars     Premium       13  683.615385
# 38384                  Midsize Cars     Premium       13  683.615385
# 38385                   Two Seaters     Premium       13  683.615385
# 38386                  Compact Cars     Premium       13  683.615385
# 38387                  Compact Cars     Premium       13  683.615385
# 38388                  Midsize Cars     Premium       13  683.615385
# 38389                  Midsize Cars     Premium       13  683.615385
# 38390                   Two Seaters     Premium       13  683.615385
# 38391                    Large Cars     Premium       12  740.583333
# 38392               Subcompact Cars     Premium       13  683.615385
# 38393               Subcompact Cars     Premium       13  683.615385
# 38396               Subcompact Cars     Regular       26  341.807692
# 38397               Subcompact Cars     Regular       24  370.291667
# 38398              Minicompact Cars     Regular       23  386.391304
# 38399               Subcompact Cars     Regular       25  355.480000
# 38400               Subcompact Cars     Regular       26  341.807692
# 38401               Subcompact Cars     Regular       26  341.807692
# 38402               Subcompact Cars     Regular       25  355.480000
# 38403              Minicompact Cars     Regular       25  355.480000
#
#        transmision_imp  desplazamiento_imp  cilindros_imp
# 0      Automatic 3-spd                 2.5            4.0
# 1      Automatic 3-spd                 2.5            4.0
# 2      Automatic 3-spd                 4.2            6.0
# 3      Automatic 3-spd                 4.2            6.0
# 4      Automatic 3-spd                 2.5            4.0
# 5      Automatic 3-spd                 4.2            6.0
# 6      Automatic 4-spd                 3.8            6.0
# 7      Automatic 4-spd                 2.2            4.0
# 8         Manual 5-spd                 2.2            4.0
# 9      Automatic 4-spd                 3.0            6.0
# 10     Automatic 4-spd                 2.3            4.0
# 11        Manual 5-spd                 2.3            4.0
# 12     Automatic 4-spd                 3.0            6.0
# 13     Automatic 4-spd                 2.3            4.0
# 14        Manual 5-spd                 2.3            4.0
# 15     Automatic 4-spd                 3.0            6.0
# 16     Automatic 4-spd                 2.5            5.0
# 17     Automatic 4-spd                 2.5            5.0
# 18     Automatic 4-spd                 3.2            6.0
# 19     Automatic 4-spd                 2.5            5.0
# 20     Automatic 4-spd                 3.2            6.0
# 21     Automatic 4-spd                 2.5            5.0
# 22     Automatic 4-spd                 3.2            6.0
# 23      Automatic (S5)                 3.2            6.0
# 24      Automatic (S5)                 3.2            6.0
# 25        Manual 6-spd                 3.2            6.0
# 26      Automatic (S5)                 3.2            6.0
# 27     Automatic 4-spd                 3.2            6.0
# 28     Automatic 5-spd                 3.2            6.0
# 29      Automatic (S5)                 3.2            6.0
# ...                ...                 ...            ...
# 38370  Automatic 4-spd                 2.9            6.0
# 38371  Automatic 4-spd                 2.9            6.0
# 38372  Automatic 4-spd                 2.9            6.0
# 38373  Automatic 4-spd                 2.9            6.0
# 38374  Automatic 4-spd                 2.9            6.0
# 38375  Automatic 4-spd                 2.9            6.0
# 38376  Automatic 4-spd                 2.9            6.0
# 38379  Automatic 4-spd                 5.6            8.0
# 38380  Automatic 4-spd                 5.6            8.0
# 38381  Automatic 4-spd                 5.6            8.0
# 38382  Automatic 4-spd                 5.6            8.0
# 38383  Automatic 4-spd                 5.6            8.0
# 38384  Automatic 4-spd                 5.6            8.0
# 38385  Automatic 4-spd                 5.6            8.0
# 38386  Automatic 4-spd                 5.6            8.0
# 38387  Automatic 4-spd                 5.6            8.0
# 38388  Automatic 4-spd                 5.6            8.0
# 38389  Automatic 4-spd                 5.6            8.0
# 38390  Automatic 4-spd                 5.6            8.0
# 38391  Automatic 4-spd                 6.0           12.0
# 38392  Automatic 4-spd                 5.0           12.0
# 38393     Manual 6-spd                 5.0           12.0
# 38396     Manual 4-spd                 1.1            4.0
# 38397     Manual 5-spd                 1.3            4.0
# 38398     Manual 4-spd                 1.3            4.0
# 38399     Manual 5-spd                 1.3            4.0
# 38400     Manual 4-spd                 1.1            4.0
# 38401     Manual 4-spd                 1.1            4.0
# 38402     Manual 5-spd                 1.3            4.0
# 38403     Manual 4-spd                 1.1            4.0
#
# [36980 rows x 14 columns]

# %% [markdown]
# 3. Imputacion de datos: Remplazar los valores inexistentes por un valor en particular, pero que esta elegido con cierto criterio. Practicas comunes de imputacion de datos son remplazar los valores de una variables con su media,moda o mediana.

# %%
#Obtenemos los valores de moda para trasmision y cilindros, para deplazamiento la media
transmision_moda=vehiculos.transmision.mode().values[0]
cilindros_moda=vehiculos.cilindros.mode().values[0]
desplazamiento_mediana=vehiculos.desplazamiento.median()

# %% [markdown]
# Rellenamos los valores nulos de las columnas de cilindros y transmision  con su moda , rellaenamos desplazamiento con la media

# %%
vehiculos.transmision=vehiculos.transmision.fillna(transmision_moda)
vehiculos.desplazamiento=vehiculos.desplazamiento.fillna(desplazamiento_mediana)
vehiculos.cilindros=vehiculos.cilindros.fillna(cilindros_moda)

# %%
vehiculos[vehiculos.transmision_imp=="sin transmision"]
# Out:
#       fabricante           model  year  desplazamiento  cilindros  \
# 15458        GMC  C25 Pickup 2WD  1984             4.1        6.0
#
#            transmision       traccion                       clase combustible  \
# 15458  Automatic 4-spd  2-Wheel Drive  Standard Pickup Trucks 2WD     Regular
#
#        consumo         co2  transmision_imp  desplazamiento_imp  cilindros_imp
# 15458       14  634.785714  sin transmision                 4.1            6.0

# %%
#Eliminamos las columnas creadas
vehiculos=vehiculos.drop(["desplazamiento_imp","transmision_imp","cilindros_imp"],axis=1)

# %% [markdown]
# Otras tecnicas incluye:
# - Usar un modelo predictivo para predecir los valores inexistentes, usando como informacion los records con la informacion completa
# - Metodos mas sofisticados MICE, en este repositori hay mas metodos
# Aqui hay algunas estrategias

# %% [markdown]
# ## Normalizacion/Estandarizacion de variables
# Hay dos formas en las cuales un dataset puede tener variables que haya que modificar pese a que no sean nulas/repetidas.
# Generalmente en un dataset las variables van a tener rangos muy distintos.

# %%
vehiculos.describe()
# Out:
#                year  desplazamiento     cilindros       consumo           co2
# count  36980.000000    36980.000000  36980.000000  36980.000000  36980.000000
# mean    2000.414575        3.299281      5.712547     19.849189    470.884255
# std       10.468370        1.318489      1.701185      4.367950    104.225851
# min     1984.000000        1.000000      2.000000      9.000000    144.000000
# 25%     1991.000000        2.200000      4.000000     17.000000    398.000000
# 50%     2001.000000        3.000000      6.000000     19.000000    467.736842
# 75%     2010.000000        4.300000      6.000000     23.000000    522.764706
# max     2018.000000        8.400000     12.000000     33.000000    796.000000

# %% [markdown]
# Por ejemplo, vemos que la variable disĺ tiene un rango de [0,8.4], mientras que la varible co2 tiene un rango[0,1270]. Al aplicar ciertos tipos de modelos lo va ha pasar es que la variable co2 va a tener mucho mas peso simplemente por que los valores que toma son mas grandes.
#
# De igual igual forma, hay variables donde la variacion de los datos es muy grande, esto hace que ciertos modelos sea mas dificil el aprender reglas consistentes.Por ejemplo la variable desplazamiento.

# %%
vehiculos.desplazamiento.plot.kde()

# %% [markdown]
# Vemos que esta variable desplazamiento tiene un coeficiente de simetria claramente positivo con un peso mayor en la izquierda.

# %%
stats.skew(vehiculos.desplazamiento)
# Out:
# 0.6347387657482069

# %% [markdown]
# Hay dos tecnicas principales para corregir estos dos tipos de problemas y mejorar nuestros modelos.

# %% [markdown]
# # Normalizacion
# Tambien se le llama min-max scaling
#
# Normalizacion convierte una variable numerica con un rango[0,1]. Muchos modelos de deep learning exigen esto como requisito.

# %%
desplazamiento_x_min=vehiculos.desplazamiento.min()
desplazamiento_x_max=vehiculos.desplazamiento.max()

desplazamiento_original=vehiculos.desplazamiento
#Para cada record se le resta el minimo y se divide entre el desplazamiento maximo menos el minimo
desplazamiento_normalizado=desplazamiento_original.apply(lambda x: (x-desplazamiento_x_min)/(desplazamiento_x_max-desplazamiento_x_min))

desplazamiento_normalizado.plot.hist(label="normalizado")
desplazamiento_original.plot.hist(label="original")
plt.legend();

# %% [markdown]
# # Estandarizacion.
# Es rescalar la variable a una distribucion con media 0 y desviacion estandar 1.
#
# Muchos algoritmos nesesitan que todas las variables tengan una distribucion normal. De hecho, la libreria principal que vamos a usar para machine learning lo especifica en su documentacion.
#
# Estandarizacion se puede realizar facilmente convirtiendo cada valor con su puntacion Z, con la formula:
#
# $$z(x)=\frac{x-\mu}{\sigma}$$

# %%
desplazamiento_mu=vehiculos.desplazamiento.mean()
desplazamiento_sigma=vehiculos.desplazamiento.std()
desplazamiento_estandarizado=desplazamiento_original.apply(lambda x:(x-desplazamiento_mu)/desplazamiento_sigma)

desplazamiento_estandarizado.plot.hist(label="standarizado",alpha=0.5)
desplazamiento_original.plot.hist(label="original",alpha=0.5)
plt.legend();

# %% [markdown]
# En cuanto elegir normalizacion o estandarizacion, esta desicion esta sujeta a debate.
#
# Si los algoritmos que se desea usar se requiere una estructura de los datos concreta, entonces no hay que tomar desicion , simplemente seguir lid requisitos de decho algoritmo.
#
# Un problema que tiene la normalizacion es que la distancia absoluta entre los valores del dataset al agruparlos todos en un grupo tan pequeño. Por lo tanto si los datos varian mucho es mejor probar a estandarizar primero en vez de normalizar. No obstante no es mala idea probar a mbos procesos y ver cual da los mejores resultados.

# %% [markdown]
# Por ejemplo vamos a hacer un grafico de dispersion para ver la comparacion de las variables displ(desplazamiento del motor) y comb08(consumo de combustible) en funcion de si estan noralizadas o estandarizadas.

# %%
consumo_original=vehiculos.consumo

consumo_mu=consumo_original.mean()
consumo_sigma=consumo_original.std()
consumo_max=consumo_original.max()
consumo_min=consumo_original.min()

consumo_estandarizado=consumo_original.apply(lambda x:(x-consumo_mu)/(consumo_sigma))
consumo_normalizado=consumo_original.apply(lambda x:(x-consumo_min)/(consumo_max-consumo_min))

# %%
plt.scatter(x=consumo_original,y=desplazamiento_original,label="original")
plt.scatter(x=consumo_estandarizado,y=desplazamiento_estandarizado,label="estandarizado")
plt.scatter(x=consumo_normalizado,y=desplazamiento_normalizado,label="normalizado")

plt.xlabel("consumo")
plt.ylabel("desplazamiento")
plt.title("Diferencias entre diferentes tipos de resxalado de variables")
plt.legend();

# %% [markdown]
# Vemos que cuando las variables estan estadarizadas, pese a que su rango es menor (entre -3 y 3 aproximadamente) vemos que refleja la relacion entre ambas variables(incluyendo el outlier en comb08).
#
# Cuando las variables estan normalizadas al estar "encajonadas" en el intervalo [0,1] cuesta ver mas su relacion cuando se comparan con la distribucion original.
#
# Esto no implica que dicha relacion de la distribucion se altere, simplemente que los valores se separan de los elementos de la variable se ven reducidos. Esto altera como cieros métodos de aprendizaje alcanzan soluciones optimas.

# %%
plt.scatter(x=consumo_normalizado,y=desplazamiento_normalizado,label="Normalizado")

# %% [markdown]
# En nuestro caso decidimos asignar dos columnas nuevas como las variables estandarizadas

# %%
vehiculos["consumo_std"]=consumo_estandarizado
vehiculos["desplazamiento_std"]=desplazamiento_estandarizado

# %%
vehiculos.head()
# Out:
#    fabricante                model  year  desplazamiento  cilindros  \
# 0  AM General    DJ Po Vehicle 2WD  1984             2.5        4.0
# 1  AM General    DJ Po Vehicle 2WD  1984             2.5        4.0
# 2  AM General     FJ8c Post Office  1984             4.2        6.0
# 3  AM General     FJ8c Post Office  1984             4.2        6.0
# 4  AM General  Post Office DJ5 2WD  1985             2.5        4.0
#
#        transmision          traccion                        clase combustible  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD     Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD     Regular
# 2  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD     Regular
# 3  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD     Regular
# 4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD     Regular
#
#    consumo         co2  consumo_std  desplazamiento_std
# 0       17  522.764706    -0.652294           -0.606210
# 1       17  522.764706    -0.652294           -0.606210
# 2       13  683.615385    -1.568056            0.683145
# 3       13  683.615385    -1.568056            0.683145
# 4       16  555.437500    -0.881235           -0.606210

# %% [markdown]
# Finalmente, guardamos a csv el dataset_limpio

# %%
vehiculos.to_csv("/home/jose/data/vehiculos_procesado.csv",index=False)
