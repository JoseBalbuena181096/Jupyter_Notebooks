# %%
#Marca de agua para informcion del sistema
# %load_ext watermark
# %watermark
# Out:
# 2018-12-20T01:19:39-06:00
#
# CPython 3.6.7
# IPython 7.2.0
#
# compiler   : GCC 8.2.0
# system     : Linux
# release    : 4.15.0-42-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %%
#Importamos pandas
import pandas as pd
#leemos el csv y cambiamos el nombre de las columnas
df=pd.read_csv("/home/jose/data/boston_dataset.csv")

# %%
#Cambiamos el nombre de las columnas
df=df.rename(columns={
    "TOWN":"CIUDAD",
    "CRIM":"INDICE_CRIMEN",
    "ZN":"PCT_ZONA_RESIDENCIAL",
    "INDUS":"PCT_ZONA_INDUSTRIAL",
    "CHAS":"RIO_CHARLES",
    "NOX":"OXIDO_NITROSO_PPM",
    "RM":"N_HABITACIONES_MEDIO",
    "AGE":"PTC_CASAS_405",
    "DIS_EMPLEO":"DISTANCIA_CENTRO_EMPLEO",
    "RAD":"DIS_AUTOPISTAS",
    "TAX":"CARGA_FISCAL",
    "PTRATIO":"RATIO_PROFESORES",
    "B":"PCT_NEGRA",
    "MEDV":"VALOR_MEDIANO",
    "LSTAT":"PTC_CLASE_BAJA"
})
df.head()
# Out:
#        CIUDAD     LON      LAT  VALOR_MEDIANO  INDICE_CRIMEN  \
# 0      Nahant -70.955  42.2550           24.0        0.00632
# 1  Swampscott -70.950  42.2875           21.6        0.02731
# 2  Swampscott -70.936  42.2830           34.7        0.02729
# 3  Marblehead -70.928  42.2930           33.4        0.03237
# 4  Marblehead -70.922  42.2980           36.2        0.06905
#
#    PCT_ZONA_RESIDENCIAL  PCT_ZONA_INDUSTRIAL  RIO_CHARLES  OXIDO_NITROSO_PPM  \
# 0                  18.0                 2.31            0              0.538
# 1                   0.0                 7.07            0              0.469
# 2                   0.0                 7.07            0              0.469
# 3                   0.0                 2.18            0              0.458
# 4                   0.0                 2.18            0              0.458
#
#    N_HABITACIONES_MEDIO  PTC_CASAS_405     DIS  DIS_AUTOPISTAS  CARGA_FISCAL  \
# ...

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
#Creamos una grafica de dispercion   , añadir que el marcador sea rosa y rosa, podemos modificar el tamaño con figsize 
#en pulgadas
df.plot.scatter(x="N_HABITACIONES_MEDIO",y="VALOR_MEDIANO",marker="*",
                color="pink",figsize=(8,8))
#Poner un titulo a la grafica creada con 
plt.title("Relacion entre el numero de habitaciones y el valor de las viviendas")
#Poner etiquetas para y
plt.xlabel("Numero medio de habitaciones")
#Poner etiquetas para x
plt.ylabel("Valor mediano de las viviendas(miles de dolares)")
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# Text(0, 0.5, 'Valor mediano de las viviendas(miles de dolares)')

# %%
#Podemos modificar los parametros de las graficas como
import matplotlib as mpl
mpl.rcParams["figure.figsize"]=(8,8)

# %%
df.plot.scatter(x="N_HABITACIONES_MEDIO",y="VALOR_MEDIANO",marker="+",color="red")
#Poner un titulo a la grafica creada con 
plt.title("Relacion entre el numero de habitaciones y el valor de las viviendas")
#Poner etiquetas para y
plt.xlabel("Numero medio de habitaciones")
#Poner etiquetas para x
plt.ylabel("Valor mediano de las viviendas(miles de dolares)")
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# Text(0, 0.5, 'Valor mediano de las viviendas(miles de dolares)')

# %%
#Matplolib tiene diversos estilos
#Saber los estilos disponibles
plt.style.available
# Out:
# ['classic',
#  'seaborn-pastel',
#  'fivethirtyeight',
#  'seaborn-poster',
#  'seaborn-deep',
#  'seaborn-whitegrid',
#  'seaborn-ticks',
#  'seaborn-colorblind',
#  'seaborn-bright',
#  'seaborn-notebook',
#  '_classic_test',
#  'seaborn-talk',
#  'fast',
#  'ggplot',
#  'seaborn-white',
#  'seaborn-dark-palette',
#  'tableau-colorblind10',
#  'Solarize_Light2',
#  'seaborn-dark',
#  'bmh',
#  'seaborn-darkgrid',
#  'seaborn',
#  'dark_background',
#  'grayscale',
#  'seaborn-muted',
#  'seaborn-paper']

# %%
#Utilizar un estilo
plt.style.use("fivethirtyeight")

# %%
df.plot.scatter(x="N_HABITACIONES_MEDIO",y="VALOR_MEDIANO")
#Poner un titulo a la grafica creada con 
plt.title("Relacion entre el numero de habitaciones y el valor de las viviendas")
#Poner etiquetas para y
plt.xlabel("Numero medio de habitaciones")
#Poner etiquetas para x
plt.ylabel("Valor mediano de las viviendas(miles de dolares)")
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# Text(0, 0.5, 'Valor mediano de las viviendas(miles de dolares)')

# %%
#Funcion para la explotacion de datos
from ipywidgets import interact

# %%
#funcion para crear funciones con relacion al valor medio de las casas
@interact(col1=df.columns.tolist())
def grafico_variable(col1):
    df.plot.scatter(x=col1,y="VALOR_MEDIANO")
    plt.title("{} vs VALOR_MEDIANO".format(col1))
#grafico_variable("INDICE_CRIMEN")
# Out:
# interactive(children=(Dropdown(description='col1', options=('CIUDAD', 'LON', 'LAT', 'VALOR_MEDIANO', 'INDICE_C…

# %%
# %matplotlib notebook
df.plot.scatter(x="LON",y="LAT")
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
#Importamos librerias para utilizar mapas
import cartopy.crs as ccrs
from cartopy.io import img_tiles

# %%
# %matplotlib notebook
df.VALOR_MEDIANO.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
#Utilizamos el primer quintil
primer_quintil=df.VALOR_MEDIANO.quantile(0.2)
primer_quintil
# Out:
# 15.3

# %%
#Utilizamos el cuarto
cuarto_quintil=df.VALOR_MEDIANO.quantile(0.8)
cuarto_quintil
# Out:
# 28.2

# %%
# %matplotlib notebook
#Creamos una imagen de Google
imagery=img_tiles.GoogleTiles()
#API DE MATPLOTLIB
ax=plt.axes(projection=imagery.crs)
#Coordenadas del mapa
limites_mapa=(-71.38,-70.77,42.03,42.47)
ax.set_extent(limites_mapa)
ax.add_image(imagery,10)
#Para imprimir los datos menores del primer quintil 
df_primer_qt=df[df.VALOR_MEDIANO<primer_quintil]
#Para imprimir los datos mayores del cuarto quintil 
df_cuarto_qt=df[df.VALOR_MEDIANO>cuarto_quintil]
#Imprimimos mapas para cada quintil
#transform=ccrs.Geodetic() para transforlar LON Y LAT en pixeles
plt.plot(df_cuarto_qt.LON,df_primer_qt.LAT,transform=ccrs.Geodetic(),marker=".",
         markersize=10,color="red",linewidth=0,alpha=0.2)
plt.plot(df_primer_qt.LON,df_primer_qt.LAT,transform=ccrs.Geodetic(),marker=".",
         markersize=10,color="blue",linewidth=0,alpha=0.2)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
#El modulo es un extencion de matplotlib para facilitar 
#Larepresentacion de ciertas graficas
import seaborn as sns
#Graficamos para N_NUMERO_HABITACIONES VS VALOR_MEDIANO
#Graficar una linea de regresion lineal
sns.lmplot(x="N_HABITACIONES_MEDIO",y="VALOR_MEDIANO",data=df)
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
#Mostramos mapas de calor para establecer la correlacion entre variables
# %matplotlib inline
sns.heatmap(df.corr())
#La correlacion indica si una variable aumenta la otra tambies y esta es 
#positiva

# %%
#importamos Bokeh 
import bokeh.plotting as bk
#Como estamos trabajando en un notebook hay que decirle a 
#bokeh que estamos en uno
bk.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1231">Loading BokehJS ...</span>
#     </div>

# %%
#bokeh es una libreria imperativa
#mostramos el indice crimen 
df.INDICE_CRIMEN
# Out:
# 0       0.00632
# 1       0.02731
# 2       0.02729
# 3       0.03237
# 4       0.06905
# 5       0.02985
# 6       0.08829
# 7       0.14455
# 8       0.21124
# 9       0.17004
# 10      0.22489
# 11      0.11747
# 12      0.09378
# 13      0.62976
# 14      0.63796
# 15      0.62739
# 16      1.05393
# 17      0.78420
# 18      0.80271
# 19      0.72580
# 20      1.25179
# 21      0.85204
# 22      1.23247
# 23      0.98843
# 24      0.75026
# 25      0.84054
# 26      0.67191
# 27      0.95577
# 28      0.77299
# 29      1.00245
#          ...
# 476     4.87141
# 477    15.02340
# 478    10.23300
# 479    14.33370
# 480     5.82401
# 481     5.70818
# 482     5.73116
# 483     2.81838
# 484     2.37857
# 485     3.67367
# 486     5.69175
# 487     4.83567
# 488     0.15086
# 489     0.18337
# 490     0.20746
# 491     0.10574
# 492     0.11132
# 493     0.17331
# 494     0.27957
# 495     0.17899
# 496     0.28960
# 497     0.26838
# 498     0.23912
# 499     0.17783
# ...

# %%
#Son muchos datos por lo que usaremos un quintil
df["CRIMEN_QUINTIL"]=pd.qcut(df.INDICE_CRIMEN,5)
#Observamos las categorias de los quintiles para el 
#el indice de delincuencia
df.CRIMEN_QUINTIL.cat.categories
# Out:
# IntervalIndex([(0.00532, 0.0642], (0.0642, 0.15], (0.15, 0.55], (0.55, 5.581], (5.581, 88.976]]
#               closed='right',
#               dtype='interval[float64]')

# %%
#Importamos la paleta de colores
from bokeh.palettes import brewer
#asignamos colores por cada quintil
colors=brewer["Spectral"][len(df.CRIMEN_QUINTIL.unique())]
colors
# Out:
# ['#2b83ba', '#abdda4', '#ffffbf', '#fdae61', '#d7191c']

# %%
p=bk.figure(
    #Medida en pixeles
    plot_width=600,
    plot_height=600,
    title="Habitaciones vs Valor vivienda vs crimen"
)
#Para cada quintil poner los puntos con color diferente
for i,quintil in enumerate(df.CRIMEN_QUINTIL.cat.categories):
    #Filtramos para cada quintil
    df_q=df[df.CRIMEN_QUINTIL==quintil]
    #Damos caracteisticas de color unico a cada quintil
    p.scatter(df_q.N_HABITACIONES_MEDIO,df_q.VALOR_MEDIANO,color=colors[i]
             ,legend="({}-{})".format(quintil.left,quintil.right))
#Mostramos la grafica
bk.show(p)
# Out:
#   <div class="bk-root" id="76e38ae0-58d3-4927-9770-4b6dffc3088e"></div>

# %%
#histograma en pandas
df.VALOR_MEDIANO.plot.hist()

# %%
#Hacer histograma con bokeh
import numpy as np
hist,edges=np.histogram(df.VALOR_MEDIANO,bins=20)

# %%
hist#El numero de la frecuencia de cada categoria
# Out:
# array([ 9, 12, 18, 36, 41, 41, 84, 71, 72, 12, 23, 18, 17, 14,  6,  1,  5,
#         5,  2, 19])

# %%
#Los valores de cada categoria
edges
# Out:
# array([ 5.  ,  7.25,  9.5 , 11.75, 14.  , 16.25, 18.5 , 20.75, 23.  ,
#        25.25, 27.5 , 29.75, 32.  , 34.25, 36.5 , 38.75, 41.  , 43.25,
#        45.5 , 47.75, 50.  ])

# %%
#Creamos otra figura de bokeh
p1=bk.figure(title="Histograma valor viviendad",tools="save,hover",background_fill_color="#F1DDCC")
#Para crear bloques
#El valor maximo hist y el minimo 0 para la altura de bloques
#Left inicio primer elemento , fin penultimo elemento y right inicio segundo elemento y fin ultimo elemento
p1.quad(top=hist,bottom=0,left=edges[:-1],right=edges[1:],fill_color="#026560")
bk.show(p1)
# Out:
#   <div class="bk-root" id="71b5b021-408e-4503-9e33-5c8d174a0ee7"></div>

# %%
#Libreria Altair
from altair import Chart,Color,Scale

# %%
chart=Chart(df)
scale=Scale(range=['#996666', 'b34d4d', '#cc3333', '#e61919', '#ff00000'])
chart.mark_point().encode(
  x="N_HABITACIONES_MEDIO",
    y="VALOR_MEDIANO",
    color=Color("CRIMEN_QUINTIL",scale=scale)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/altair/vegalite/v2/api.py in to_dict(self, *args, **kwargs)
#     400         copy = self.copy()
#     401         original_data = getattr(copy, 'data', Undefined)
# --> 402         copy.data = _prepare_data(original_data, context)
#     403
#     404         if original_data is not Undefined:
#
# ~/.local/lib/python3.6/site-packages/altair/vegalite/v2/api.py in _prepare_data(data, context)
#      90     # consolidate inline data to top-level datasets
#      91     if data_transformers.consolidate_datasets:
# ---> 92         data = _consolidate_data(data, context)
#      93
#      94     # if data is still not a recognized type, then return
#
# ~/.local/lib/python3.6/site-packages/altair/vegalite/v2/api.py in _consolidate_data(data, context)
#      57
#      58     if values is not Undefined:
# ...
